# %% [markdown]
# # Data Cleaning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
filename = '/content/drive/MyDrive/Colab Notebooks/Data Science - Coding Dojo/Proyecto1/sales_predictions.csv'
df = pd.read_csv(filename)
print(df)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Se crea un respaldo del df original bajo el nombre de df1
df1 = df

# %%
df1.isnull().sum()
# Podemos observar que las columnas con datos faltantes son aquellas correspondientes al peso de los ítems y al tamaño de las tiendas
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
null1 = df1['Item_Weight'].isnull()

# %%
df_weight_null = df1[null1]
df_weight_null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 23             Baking Goods  107.6938            OUT019
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                          1985      Medium               Tier 3
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 23                         1985       Small               Tier 1
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8485                       1985      Medium               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8490                       1985       Small               Tier 1
# 8504                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %%
df_weight_null['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    213
# Snack Foods              212
# Household                151
# Frozen Foods             138
# Dairy                    116
# Baking Goods             112
# Canned                   110
# Health and Hygiene        90
# Meat                      88
# Soft Drinks               71
# Breads                    47
# Others                    32
# Hard Drinks               31
# Breakfast                 21
# Starchy Foods             18
# Seafood                   13
# Name: Item_Type, dtype: int64

# %%
df_weight_null['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    867
# Regular    501
# LF          56
# low fat     28
# reg         11
# Name: Item_Fat_Content, dtype: int64

# %%
df_weight_null['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df_weight_null['Item_Identifier'].value_counts()
# Out:
# FDK08    2
# FDA08    2
# FDV23    2
# FDY56    2
# FDI04    2
#         ..
# FDM44    1
# FDZ48    1
# FDK41    1
# FDD57    1
# NCN18    1
# Name: Item_Identifier, Length: 1142, dtype: int64

# %%
df1[df['Item_Identifier']=='FDV23']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 1096           FDV23         11.0          Low Fat         0.106051    Breads
# 3896           FDV23          NaN          Low Fat         0.185307    Breads
# 4516           FDV23          NaN          Low Fat         0.105324    Breads
# 6045           FDV23         11.0               LF         0.106268    Breads
# 8370           FDV23         11.0          Low Fat         0.105817    Breads
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 1096  124.4046            OUT045                       2002         NaN
# 3896  125.6046            OUT019                       1985       Small
# 4516  125.7046            OUT027                       1985      Medium
# 6045  123.2046            OUT018                       2009      Medium
# 8370  126.0046            OUT035                       2004       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 1096               Tier 2  Supermarket Type1          2241.0828
# 3896               Tier 1      Grocery Store           622.5230
# 4516               Tier 3  Supermarket Type3          3237.1196
# 6045               Tier 3  Supermarket Type2          3237.1196
# 8370               Tier 2  Supermarket Type1           871.5322

# %%
df_weight_null[df_weight_null['Item_Identifier'] == 'FDV23']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 3896           FDV23          NaN          Low Fat         0.185307    Breads
# 4516           FDV23          NaN          Low Fat         0.105324    Breads
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 3896  125.6046            OUT019                       1985       Small
# 4516  125.7046            OUT027                       1985      Medium
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 3896               Tier 1      Grocery Store           622.5230
# 4516               Tier 3  Supermarket Type3          3237.1196

# %%
df1[df['Item_Identifier']=='FDV23']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 1096           FDV23         11.0          Low Fat         0.106051    Breads
# 3896           FDV23          NaN          Low Fat         0.185307    Breads
# 4516           FDV23          NaN          Low Fat         0.105324    Breads
# 6045           FDV23         11.0               LF         0.106268    Breads
# 8370           FDV23         11.0          Low Fat         0.105817    Breads
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 1096  124.4046            OUT045                       2002         NaN
# 3896  125.6046            OUT019                       1985       Small
# 4516  125.7046            OUT027                       1985      Medium
# 6045  123.2046            OUT018                       2009      Medium
# 8370  126.0046            OUT035                       2004       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 1096               Tier 2  Supermarket Type1          2241.0828
# 3896               Tier 1      Grocery Store           622.5230
# 4516               Tier 3  Supermarket Type3          3237.1196
# 6045               Tier 3  Supermarket Type2          3237.1196
# 8370               Tier 2  Supermarket Type1           871.5322

# %%
df1[df['Item_Identifier']=='FDV23']['Item_Weight'].mode()
# Out:
# 0    11.0
# dtype: float64

# %%
df_weight_null[df_weight_null['Item_Identifier'] == 'FDV23']['Item_Weight'].fillna(df1[df['Item_Identifier']=='FDV23']['Item_Weight'].mode()[0])
# Out:
# 3896    11.0
# 4516    11.0
# Name: Item_Weight, dtype: float64

# %%
items_id = df1[null1]['Item_Identifier'].unique()
len(items_id)
# Out:
# 1142

# %%
df_weight_null_ri = df_weight_null.reset_index()
df_weight_null_ri
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         7           FDP10          NaN          Low Fat         0.127470
# 1        18           DRI11          NaN          Low Fat         0.034238
# 2        21           FDW12          NaN          Regular         0.035400
# 3        23           FDC37          NaN          Low Fat         0.057557
# 4        29           FDC14          NaN          Regular         0.072222
# ...     ...             ...          ...              ...              ...
# 1458   8485           DRK37          NaN          Low Fat         0.043792
# 1459   8487           DRG13          NaN          Low Fat         0.037006
# 1460   8488           NCN14          NaN          Low Fat         0.091473
# 1461   8490           FDU44          NaN          Regular         0.102296
# 1462   8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0               Snack Foods  107.7622            OUT027
# 1               Hard Drinks  113.2834            OUT027
# 2              Baking Goods  144.5444            OUT027
# 3              Baking Goods  107.6938            OUT019
# 4                    Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 1458            Soft Drinks  189.0530            OUT027
# 1459            Soft Drinks  164.7526            OUT027
# 1460                 Others  184.6608            OUT027
# 1461  Fruits and Vegetables  162.3552            OUT019
# 1462              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1985      Medium               Tier 3
# 1                          1985      Medium               Tier 3
# 2                          1985      Medium               Tier 3
# 3                          1985       Small               Tier 1
# 4                          1985       Small               Tier 1
# ...                         ...         ...                  ...
# 1458                       1985      Medium               Tier 3
# 1459                       1985      Medium               Tier 3
# 1460                       1985      Medium               Tier 3
# 1461                       1985       Small               Tier 1
# 1462                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type3          4022.7636
# 1     Supermarket Type3          2303.6680
# 2     Supermarket Type3          4064.0432
# 3         Grocery Store           214.3876
# 4         Grocery Store           125.8362
# ...                 ...                ...
# 1458  Supermarket Type3          6261.8490
# 1459  Supermarket Type3          4111.3150
# 1460  Supermarket Type3          2756.4120
# 1461      Grocery Store           487.3656
# 1462  Supermarket Type3          4138.6128
#
# [1463 rows x 13 columns]

# %%
leng = df_weight_null_ri
for i in range (len(leng)):
  moda = df1[df['Item_Identifier']==leng.loc[i,'Item_Identifier']]['Item_Weight'].mode()
  for j in range (len(moda)):
    df_weight_null.iloc[i,1] = moda[0]
    # print(moda[j])
    # df_weight_null[df_weight_null['Item_Identifier'] == items_id[i]]['Item_Weight'].fillna(moda[0], inplace=True)
    # df_weight_null[df_weight_null['Item_Identifier'] == items_id[i]]['Item_Weight'] = moda[0]
      # A value is trying to be set on a copy of a slice from a DataFrame.
      # Try using .loc[row_indexer,col_indexer] = value instead"""
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_weight_null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10       19.000          Low Fat         0.127470
# 18             DRI11        8.260          Low Fat         0.034238
# 21             FDW12        8.315          Regular         0.035400
# 23             FDC37       15.500          Low Fat         0.057557
# 29             FDC14       14.500          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37        5.000          Low Fat         0.043792
# 8487           DRG13       17.250          Low Fat         0.037006
# 8488           NCN14       19.100          Low Fat         0.091473
# 8490           FDU44       12.150          Regular         0.102296
# 8504           NCN18        8.895          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 23             Baking Goods  107.6938            OUT019
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                          1985      Medium               Tier 3
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 23                         1985       Small               Tier 1
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8485                       1985      Medium               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8490                       1985       Small               Tier 1
# 8504                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %%
leng.iloc[0,1]
# Out:
# 'FDP10'

# %%
df_weight_null.loc[7,'Item_Weight']
# Out:
# 19.0

# %%
df_weight_null.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  4
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
filtro2 = df_weight_null['Item_Weight'].isnull()
df_weight_null_2 = df_weight_null[filtro2]
df_weight_null_2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927            FDN52          NaN          Regular         0.130933
# 1922           FDK57          NaN          Low Fat         0.079904
# 4187           FDE52          NaN          Regular         0.029742
# 5022           FDQ60          NaN          Regular         0.191501
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927   Frozen Foods   86.9198            OUT027                       1985
# 1922   Snack Foods  120.0440            OUT027                       1985
# 4187         Dairy   88.9514            OUT027                       1985
# 5022  Baking Goods  121.2098            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927       Medium               Tier 3  Supermarket Type3          1569.9564
# 1922      Medium               Tier 3  Supermarket Type3          4434.2280
# 4187      Medium               Tier 3  Supermarket Type3          3453.5046
# 5022       Small               Tier 1      Grocery Store           120.5098

# %%
df1[df['Item_Identifier']==df_weight_null_2.iloc[2,0]]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 4187           FDE52          NaN          Regular         0.029742     Dairy
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 4187   88.9514            OUT027                       1985      Medium
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 4187               Tier 3  Supermarket Type3          3453.5046

# %% [markdown]
# Actualizando los datos en el dt de respaldo

# %%
df1.iloc[0,0]
# Out:
# 'FDA15'

# %%
# df_weight_null = df_weight_null.reset_index()
df_weight_null
# Out:
#       level_0  index Item_Identifier  Item_Weight Item_Fat_Content  \
# 0           0      7           FDP10       19.000          Low Fat
# 1           1     18           DRI11        8.260          Low Fat
# 2           2     21           FDW12        8.315          Regular
# 3           3     23           FDC37       15.500          Low Fat
# 4           4     29           FDC14       14.500          Regular
# ...       ...    ...             ...          ...              ...
# 1458     1458   8485           DRK37        5.000          Low Fat
# 1459     1459   8487           DRG13       17.250          Low Fat
# 1460     1460   8488           NCN14       19.100          Low Fat
# 1461     1461   8490           FDU44       12.150          Regular
# 1462     1462   8504           NCN18        8.895          Low Fat
#
#       Item_Visibility              Item_Type  Item_MRP Outlet_Identifier  \
# 0            0.127470            Snack Foods  107.7622            OUT027
# 1            0.034238            Hard Drinks  113.2834            OUT027
# 2            0.035400           Baking Goods  144.5444            OUT027
# 3            0.057557           Baking Goods  107.6938            OUT019
# 4            0.072222                 Canned   43.6454            OUT019
# ...               ...                    ...       ...               ...
# 1458         0.043792            Soft Drinks  189.0530            OUT027
# 1459         0.037006            Soft Drinks  164.7526            OUT027
# 1460         0.091473                 Others  184.6608            OUT027
# 1461         0.102296  Fruits and Vegetables  162.3552            OUT019
# 1462         0.124111              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1985      Medium               Tier 3
# 1                          1985      Medium               Tier 3
# 2                          1985      Medium               Tier 3
# 3                          1985       Small               Tier 1
# 4                          1985       Small               Tier 1
# ...                         ...         ...                  ...
# 1458                       1985      Medium               Tier 3
# 1459                       1985      Medium               Tier 3
# 1460                       1985      Medium               Tier 3
# 1461                       1985       Small               Tier 1
# 1462                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type3          4022.7636
# 1     Supermarket Type3          2303.6680
# 2     Supermarket Type3          4064.0432
# 3         Grocery Store           214.3876
# 4         Grocery Store           125.8362
# ...                 ...                ...
# 1458  Supermarket Type3          6261.8490
# 1459  Supermarket Type3          4111.3150
# 1460  Supermarket Type3          2756.4120
# 1461      Grocery Store           487.3656
# 1462  Supermarket Type3          4138.6128
#
# [1463 rows x 14 columns]

# %%
for i in df_weight_null['index']:
    df1.iloc[i,1] = df_weight_null[df_weight_null['index'] == i]['Item_Weight']
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df1.iloc[8490]
# Out:
# Item_Identifier                              FDU44
# Item_Weight                                  12.15
# Item_Fat_Content                           Regular
# Item_Visibility                           0.102296
# Item_Type                    Fruits and Vegetables
# Item_MRP                                  162.3552
# Outlet_Identifier                           OUT019
# Outlet_Establishment_Year                     1985
# Outlet_Size                                  Small
# Outlet_Location_Type                        Tier 1
# Outlet_Type                          Grocery Store
# Item_Outlet_Sales                         487.3656
# Name: 8490, dtype: object

# %%
df1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     4
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# lIMPIEZA OUTLET SIZE

# %%
null2 = df1['Outlet_Size'].isnull()

# %%
df1[null2]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 25                Household   45.9060            OUT017
# 28                    Dairy   45.5086            OUT010
# ...                     ...       ...               ...
# 8502              Household  216.4192            OUT045
# 8508  Fruits and Vegetables  199.4742            OUT045
# 8509  Fruits and Vegetables  213.9902            OUT010
# 8514                 Canned   57.5904            OUT045
# 8519           Baking Goods  108.1570            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 25                         2007         NaN               Tier 2
# 28                         1998         NaN               Tier 3
# ...                         ...         ...                  ...
# 8502                       2002         NaN               Tier 2
# 8508                       2002         NaN               Tier 2
# 8509                       1998         NaN               Tier 3
# 8514                       2002         NaN               Tier 2
# 8519                       2002         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 3         Grocery Store           732.3800
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 25    Supermarket Type1           838.9080
# 28        Grocery Store           178.4344
# ...                 ...                ...
# 8502  Supermarket Type1          3020.0688
# 8508  Supermarket Type1          2587.9646
# 8509      Grocery Store           424.7804
# 8514  Supermarket Type1           468.7232
# 8519  Supermarket Type1           549.2850
#
# [2410 rows x 12 columns]

# %%
df1[null2]['Outlet_Identifier'].value_counts()
# Out:
# OUT045    929
# OUT017    926
# OUT010    555
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
